# %%
import requests
import json
import prettytable
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
import psycopg2 
import io

# %%
pd.set_option('display.max_columns', None)

# %%
#create dataframe from excel file May 2018
file_nat = "data_files/all_data_M_2018.xlsx"
bls_all_may2018= pd.read_excel(file_nat)
bls_all_may2018.head()
# Out:
#    area area_title  area_type   naics     naics_title         i_group  \
# 0    99       U.S.          1  000000  Cross-industry  cross-industry
# 1    99       U.S.          1  000000  Cross-industry  cross-industry
# 2    99       U.S.          1  000000  Cross-industry  cross-industry
# 3    99       U.S.          1  000000  Cross-industry  cross-industry
# 4    99       U.S.          1  000000  Cross-industry  cross-industry
#
#    own_code occ_code               occ_title   o_group    tot_emp emp_prse  \
# 0      1235  00-0000         All Occupations     total  144733270      0.1
# 1      1235  11-0000  Management Occupations     major    7616650      0.2
# 2      1235  11-1000          Top Executives     minor    2535640      0.3
# 3      1235  11-1010        Chief Executives     broad     195530      0.7
# 4      1235  11-1011        Chief Executives  detailed     195530      0.7
#
#   jobs_1000 loc_quotient pct_total h_mean  a_mean mean_prse h_pct10 h_pct25  \
# 0       NaN          NaN       NaN  24.98   51960       0.1    9.95   12.37
# 1       NaN          NaN       NaN  58.44  121560       0.1   23.68   34.08
# 2       NaN          NaN       NaN  61.66  128240       0.2   20.86   31.73
# 3       NaN          NaN       NaN  96.22  200140       0.5   32.86   55.75
# 4       NaN          NaN       NaN  96.22  200140       0.5   32.86   55.75
#
#   h_median h_pct75 h_pct90 a_pct10 a_pct25 a_median a_pct75 a_pct90 annual  \
# 0    18.58   30.06   47.31   20690   25740    38640   62510   98410    NaN
# 1    50.11   72.93       #   49260   70880   104240  151700       #    NaN
# 2    49.73   78.81       #   43400   66000   103450  163930       #    NaN
# 3    91.15       #       #   68360  115960   189600       #       #    NaN
# 4    91.15       #       #   68360  115960   189600       #       #    NaN
#
#   hourly
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN

# %%
bls_all_may2018.tail(5)
# Out:
#            area                                         area_title  area_type  \
# 403890  4800004  Hill Country Region of Texas nonmetropolitan area          6
# 403891  5500001        Northwestern Wisconsin nonmetropolitan area          6
# 403892  5500002        Northeastern Wisconsin nonmetropolitan area          6
# 403893  5500003       South Central Wisconsin nonmetropolitan area          6
# 403894  5500004             Western Wisconsin nonmetropolitan area          6
#
#          naics     naics_title         i_group  own_code occ_code  \
# 403890  000000  Cross-industry  cross-industry      1235  53-7199
# 403891  000000  Cross-industry  cross-industry      1235  53-7199
# 403892  000000  Cross-industry  cross-industry      1235  53-7199
# 403893  000000  Cross-industry  cross-industry      1235  53-7199
# 403894  000000  Cross-industry  cross-industry      1235  53-7199
#
#                                  occ_title   o_group tot_emp emp_prse  \
# 403890  Material Moving Workers, All Other  detailed      40     32.8
# 403891  Material Moving Workers, All Other  detailed     170     25.8
# 403892  Material Moving Workers, All Other  detailed     170     41.4
# 403893  Material Moving Workers, All Other  detailed     130     29.2
# 403894  Material Moving Workers, All Other  detailed      **       **
#
#        jobs_1000 loc_quotient pct_total h_mean a_mean mean_prse h_pct10  \
# 403890     0.193         1.04       NaN  13.41  27900       7.3   10.16
# 403891     3.473        18.61       NaN  11.74  24420       4.9    8.73
# 403892     0.863         4.63       NaN  12.91  26850       6.6   10.11
# 403893     0.632         3.39       NaN  12.35  25690       6.7    9.03
# 403894        **           **       NaN  11.93  24810       6.3     8.8
#
#        h_pct25 h_median h_pct75 h_pct90 a_pct10 a_pct25 a_median a_pct75  \
# 403890   11.15    13.27   14.99   17.09   21130   23190    27600   31170
# 403891   10.06    11.93   13.41   14.48   18160   20920    24820   27880
# 403892   10.75    11.82   14.23   18.17   21020   22360    24590   29590
# 403893   10.23    12.84   14.41   15.45   18790   21280    26710   29970
# 403894    9.99    10.95   11.91   18.29   18290   20770    22770   24760
#
#        a_pct90 annual hourly
# 403890   35550    NaN    NaN
# 403891   30130    NaN    NaN
# 403892   37790    NaN    NaN
# 403893   32130    NaN    NaN
# 403894   38040    NaN    NaN

# %%
#Count number of distinct elements in each column in this df.
bls_all_may2018.nunique()
# Out:
# area              584
# area_title        584
# area_type           5
# naics             420
# naics_title       398
# i_group             7
# own_code           10
# occ_code         1373
# occ_title        1103
# o_group             5
# tot_emp         11987
# emp_prse          501
# jobs_1000       26869
# loc_quotient     2093
# pct_total        2819
# h_mean           9719
# a_mean          17193
# mean_prse         300
# h_pct10          5599
# h_pct25          6818
# h_median         7850
# h_pct75          8729
# h_pct90          9053
# a_pct10          9900
# a_pct25         12192
# a_median        14601
# a_pct75         17070
# a_pct90         18460
# annual              1
# hourly              1
# dtype: int64

# %%
#to see all columns in the df
list_all_may2018 = bls_all_may2018.columns.to_list()
list_all_may2018
# Out:
# ['area',
#  'area_title',
#  'area_type',
#  'naics',
#  'naics_title',
#  'i_group',
#  'own_code',
#  'occ_code',
#  'occ_title',
#  'o_group',
#  'tot_emp',
#  'emp_prse',
#  'jobs_1000',
#  'loc_quotient',
#  'pct_total',
#  'h_mean',
#  'a_mean',
#  'mean_prse',
#  'h_pct10',
#  'h_pct25',
#  'h_median',
#  'h_pct75',
#  'h_pct90',
#  'a_pct10',
#  'a_pct25',
#  'a_median',
#  'a_pct75',
#  'a_pct90',
#  'annual',
#  'hourly']

# %%
# converting the table heading to lowercase
list_all_may2018_lowcase = [col.lower() for col in list_all_may2018]
list_all_may2018_lowcase
# Out:
# ['area',
#  'area_title',
#  'area_type',
#  'naics',
#  'naics_title',
#  'i_group',
#  'own_code',
#  'occ_code',
#  'occ_title',
#  'o_group',
#  'tot_emp',
#  'emp_prse',
#  'jobs_1000',
#  'loc_quotient',
#  'pct_total',
#  'h_mean',
#  'a_mean',
#  'mean_prse',
#  'h_pct10',
#  'h_pct25',
#  'h_median',
#  'h_pct75',
#  'h_pct90',
#  'a_pct10',
#  'a_pct25',
#  'a_median',
#  'a_pct75',
#  'a_pct90',
#  'annual',
#  'hourly']

# %%
bls_all_may2018.columns = list_all_may2018_lowcase

# %%
# drop unwanted columns
bls_all_may2018_clean = bls_all_may2018.drop(['area_type',
 'naics',
 'naics_title',
 'i_group',
'own_code',
 'jobs_1000',
 'loc_quotient',
'pct_total',
 'h_pct10',
 'h_pct25',
 'h_median',
 'h_pct75',
 'h_pct90',
 'a_pct10',
 'a_pct25',
 'a_median',
 'a_pct75',
 'a_pct90',
 'annual',
 'hourly'] ,axis=1)
bls_all_may2018_clean.head()
# Out:
#    area area_title occ_code               occ_title   o_group    tot_emp  \
# 0    99       U.S.  00-0000         All Occupations     total  144733270
# 1    99       U.S.  11-0000  Management Occupations     major    7616650
# 2    99       U.S.  11-1000          Top Executives     minor    2535640
# 3    99       U.S.  11-1010        Chief Executives     broad     195530
# 4    99       U.S.  11-1011        Chief Executives  detailed     195530
#
#   emp_prse h_mean  a_mean mean_prse
# 0      0.1  24.98   51960       0.1
# 1      0.2  58.44  121560       0.1
# 2      0.3  61.66  128240       0.2
# 3      0.7  96.22  200140       0.5
# 4      0.7  96.22  200140       0.5

# %%
bls_all_may2018_clean.isna().sum()
# Out:
# area          0
# area_title    0
# occ_code      0
# occ_title     0
# o_group       0
# tot_emp       0
# emp_prse      0
# h_mean        0
# a_mean        0
# mean_prse     0
# dtype: int64

# %%
# Convert columns to numeric 
cols = ['tot_emp',
 'emp_prse',
 'h_mean',
 'a_mean',
 'mean_prse',
 ]

for col in cols:
    print(col)
    bls_all_may2018_clean[col] = pd.to_numeric( bls_all_may2018_clean[col], errors='coerce')

bls_all_may2018_clean.head()
# Out:
# tot_emp
# emp_prse
# h_mean
# a_mean
# mean_prse
#    area area_title occ_code               occ_title   o_group      tot_emp  \
# 0    99       U.S.  00-0000         All Occupations     total  144733270.0
# 1    99       U.S.  11-0000  Management Occupations     major    7616650.0
# 2    99       U.S.  11-1000          Top Executives     minor    2535640.0
# 3    99       U.S.  11-1010        Chief Executives     broad     195530.0
# 4    99       U.S.  11-1011        Chief Executives  detailed     195530.0
#
#    emp_prse  h_mean    a_mean  mean_prse
# 0       0.1   24.98   51960.0        0.1
# 1       0.2   58.44  121560.0        0.1
# 2       0.3   61.66  128240.0        0.2
# 3       0.7   96.22  200140.0        0.5
# 4       0.7   96.22  200140.0        0.5

# %%
bls_all_may2018_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 403895 entries, 0 to 403894
# Data columns (total 10 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   area        403895 non-null  int64
#  1   area_title  403895 non-null  object
#  2   occ_code    403895 non-null  object
#  3   occ_title   403895 non-null  object
#  4   o_group     403895 non-null  object
#  5   tot_emp     374496 non-null  float64
#  6   emp_prse    374496 non-null  float64
#  7   h_mean      382544 non-null  float64
#  8   a_mean      396782 non-null  float64
#  9   mean_prse   397000 non-null  float64
# dtypes: float64(5), int64(1), object(4)
# memory usage: 30.8+ MB

# %%
# remove NAN in this dataframe 
bls_all_may2018_clean.dropna()
# Out:
#            area                                         area_title occ_code  \
# 0            99                                               U.S.  00-0000
# 1            99                                               U.S.  11-0000
# 2            99                                               U.S.  11-1000
# 3            99                                               U.S.  11-1010
# 4            99                                               U.S.  11-1011
# ...         ...                                                ...      ...
# 403889  4800002   North Texas Region of Texas nonmetropolitan area  53-7199
# 403890  4800004  Hill Country Region of Texas nonmetropolitan area  53-7199
# 403891  5500001        Northwestern Wisconsin nonmetropolitan area  53-7199
# 403892  5500002        Northeastern Wisconsin nonmetropolitan area  53-7199
# 403893  5500003       South Central Wisconsin nonmetropolitan area  53-7199
#
#                                  occ_title   o_group      tot_emp  emp_prse  \
# 0                          All Occupations     total  144733270.0       0.1
# 1                   Management Occupations     major    7616650.0       0.2
# 2                           Top Executives     minor    2535640.0       0.3
# 3                         Chief Executives     broad     195530.0       0.7
# 4                         Chief Executives  detailed     195530.0       0.7
# ...                                    ...       ...          ...       ...
# 403889  Material Moving Workers, All Other  detailed        190.0      20.1
# 403890  Material Moving Workers, All Other  detailed         40.0      32.8
# 403891  Material Moving Workers, All Other  detailed        170.0      25.8
# 403892  Material Moving Workers, All Other  detailed        170.0      41.4
# 403893  Material Moving Workers, All Other  detailed        130.0      29.2
#
#         h_mean    a_mean  mean_prse
# 0        24.98   51960.0        0.1
# 1        58.44  121560.0        0.1
# 2        61.66  128240.0        0.2
# 3        96.22  200140.0        0.5
# 4        96.22  200140.0        0.5
# ...        ...       ...        ...
# 403889   19.39   40320.0       11.8
# 403890   13.41   27900.0        7.3
# 403891   11.74   24420.0        4.9
# 403892   12.91   26850.0        6.6
# 403893   12.35   25690.0        6.7
#
# [353436 rows x 10 columns]

# %%
bls_all_may2018_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 403895 entries, 0 to 403894
# Data columns (total 10 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   area        403895 non-null  int64
#  1   area_title  403895 non-null  object
#  2   occ_code    403895 non-null  object
#  3   occ_title   403895 non-null  object
#  4   o_group     403895 non-null  object
#  5   tot_emp     374496 non-null  float64
#  6   emp_prse    374496 non-null  float64
#  7   h_mean      382544 non-null  float64
#  8   a_mean      396782 non-null  float64
#  9   mean_prse   397000 non-null  float64
# dtypes: float64(5), int64(1), object(4)
# memory usage: 30.8+ MB

# %%
bls_all_may2018_clean.head(5)
# Out:
#    area area_title occ_code               occ_title   o_group      tot_emp  \
# 0    99       U.S.  00-0000         All Occupations     total  144733270.0
# 1    99       U.S.  11-0000  Management Occupations     major    7616650.0
# 2    99       U.S.  11-1000          Top Executives     minor    2535640.0
# 3    99       U.S.  11-1010        Chief Executives     broad     195530.0
# 4    99       U.S.  11-1011        Chief Executives  detailed     195530.0
#
#    emp_prse  h_mean    a_mean  mean_prse
# 0       0.1   24.98   51960.0        0.1
# 1       0.2   58.44  121560.0        0.1
# 2       0.3   61.66  128240.0        0.2
# 3       0.7   96.22  200140.0        0.5
# 4       0.7   96.22  200140.0        0.5

# %%
#create CSV files to be used to load database as needed
bls_all_may2018_clean.to_csv('data_files/bls_all_may2018_clean.csv')
