# %% [markdown]
# # Technical Job Group DataFrame

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Source

# %%
demographic_df = pd.read_csv('../data_files/metro_demographic_by_city_state.csv', index_col=[0], header=0)
BLS = pd.read_csv('../data_files/bls_metro_2020_clean.csv', index_col=[0], header=0)

# %%
# remove the o_group with value detail
BLS = BLS[BLS['o_group']!='detailed']

# %%
BLS
# Out:
#          area        area_title prim_state occ_code  \
# 0       10180       Abilene, TX         TX  00-0000
# 1       10180       Abilene, TX         TX  11-0000
# 18      10180       Abilene, TX         TX  13-0000
# 34      10180       Abilene, TX         TX  15-0000
# 41      10180       Abilene, TX         TX  17-0000
# ...       ...               ...        ...      ...
# 139927  79600  Worcester, MA-CT         MA  45-0000
# 139930  79600  Worcester, MA-CT         MA  47-0000
# 139955  79600  Worcester, MA-CT         MA  49-0000
# 139980  79600  Worcester, MA-CT         MA  51-0000
# 140032  79600  Worcester, MA-CT         MA  53-0000
#
#                                                 occ_title o_group  tot_emp  \
# 0                                         All Occupations   total  66060.0
# 1                                  Management Occupations   major   2910.0
# 18          Business and Financial Operations Occupations   major   2150.0
# 34                  Computer and Mathematical Occupations   major    820.0
# 41               Architecture and Engineering Occupations   major    840.0
# ...                                                   ...     ...      ...
# 139927         Farming, Fishing, and Forestry Occupations   major    330.0
# 139930            Construction and Extraction Occupations   major   9110.0
# 139955  Installation, Maintenance, and Repair Occupations   major   9160.0
# 139980                             Production Occupations   major  18430.0
# 140032     Transportation and Material Moving Occupations   major  21710.0
#
#         emp_prse  jobs_1000  loc_quotient  ...  h_pct10  h_pct25  h_median  \
# 0            1.9   1000.000          1.00  ...     9.13    11.40     16.41
# 1            4.5     44.068          0.77  ...    17.38    26.74     36.37
# 18           5.5     32.515          0.54  ...    16.48    21.89     29.35
# 34          15.3     12.372          0.38  ...    16.47    21.02     26.51
# 41          13.1     12.765          0.71  ...    18.62    24.36     32.65
# ...          ...        ...           ...  ...      ...      ...       ...
# 139927      41.4      1.251          0.36  ...    13.32    14.20     16.17
# 139930       4.7     34.244          0.80  ...    16.48    20.21     26.65
# 139955       5.3     34.437          0.87  ...    15.79    19.98     24.95
# 139980       4.1     69.277          1.13  ...    13.35    15.16     19.30
# 140032       4.5     81.611          0.93  ...    12.97    14.16     17.11
#
#         h_pct75  h_pct90  a_pct10  a_pct25  a_median   a_pct75   a_pct90
# 0         24.82    36.23  18990.0  23710.0   34130.0   51620.0   75370.0
# 1         51.68    73.88  36150.0  55620.0   75640.0  107500.0  153670.0
# 18        38.69    50.26  34280.0  45530.0   61040.0   80470.0  104530.0
# 34        37.25    48.61  34250.0  43720.0   55130.0   77490.0  101120.0
# 41        43.04    55.23  38740.0  50660.0   67900.0   89520.0  114880.0
# ...         ...      ...      ...      ...       ...       ...       ...
# 139927    19.44    26.73  27700.0  29540.0   33640.0   40440.0   55600.0
# 139930    36.25    47.75  34280.0  42030.0   55420.0   75400.0   99320.0
# 139955    32.07    40.87  32840.0  41550.0   51890.0   66710.0   85010.0
# 139980    25.13    31.87  27770.0  31530.0   40150.0   52270.0   66280.0
# 140032    23.05    29.88  26980.0  29450.0   35590.0   47940.0   62140.0
#
# [8764 rows x 23 columns]

# %% [markdown]
# ## Prepare BLS_df with only these BLS columns

# %%
BLS_df = BLS[['area_title', 'occ_title', 'tot_emp', 'jobs_1000']]
BLS_df['tot_emp'] = BLS_df['tot_emp'].astype(int)

# Drop the rows where occ_title is 'All Occupations'
BLS_df = BLS_df[BLS_df['occ_title']!='All Occupations']
BLS_df.head(100)
# Out:
# <ipython-input-5-9f1f06dc8ef2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BLS_df['tot_emp'] = BLS_df['tot_emp'].astype(int)
#        area_title                                          occ_title  tot_emp  \
# 1     Abilene, TX                             Management Occupations     2910
# 18    Abilene, TX      Business and Financial Operations Occupations     2150
# 34    Abilene, TX              Computer and Mathematical Occupations      820
# 41    Abilene, TX           Architecture and Engineering Occupations      840
# 51    Abilene, TX     Life, Physical, and Social Science Occupations      370
# ...           ...                                                ...      ...
# 1267   Albany, OR                     Healthcare Support Occupations     2270
# 1275   Albany, OR                     Protective Service Occupations      670
# 1283   Albany, OR   Food Preparation and Serving Related Occupations     3580
# 1295   Albany, OR  Building and Grounds Cleaning and Maintenance ...      930
# 1299   Albany, OR              Personal Care and Service Occupations      590
#
#       jobs_1000
# 1        44.068
# 18       32.515
# 34       12.372
# 41       12.765
# 51        5.554
# ...         ...
# 1267     53.213
# 1275     15.744
# 1283     83.725
# 1295     21.674
# 1299     13.803
#
# [100 rows x 4 columns]

# %%
BLS_df.dtypes
# Out:
# area_title     object
# occ_title      object
# tot_emp         int64
# jobs_1000     float64
# dtype: object

# %% [markdown]
# ## Demographic_df

# %%
demographic_df.head()
# Out:
#         area_title        area_name  population  median_age  average_income  \
# 0      Abilene, TX      Abilene, TX      133731          29           52989
# 1        Akron, OH        Akron, OH      374675          38           57023
# 2       Albany, GA       Albany, GA       98002          35           53876
# 3       Albany, OR       Albany, OR       63503          38           72395
# 4  Albuquerque, NM  Albuquerque, NM      638803          36           66708
#
#    family_poverty  educational_attainment_bachelors  \
# 0           16198                             19975
# 1           52405                             60910
# 2           24957                             11517
# 3            6409                             11043
# 4           92558                            111538
#
#    educational_attainment_graduate  educational_attainment_high_school  \
# 0                             9695                               40965
# 1                            29186                              132252
# 2                             8460                               29032
# 3                             5806                               15482
# 4                            91807                              152964
#
#    educational_attainment_no_diploma  educational_attainment_some_college  \
# 0                              19258                                43669
# 1                              41708                               110658
# 2                              16919                                32046
# 3                               5150                                26013
# 4                              78799                               203804
#
#    race_asian  race_white  race_black  race_hispanic  race_native  \
# 0        2626       81145       12275          34147          689
# 1        9945      279041       66305           7245          784
# 2         959       28981       63178           2916          119
# 3        1185       52553         367           7282          410
# 4       14485      252843       16466         317922        22924
#
#    race_islander  race_two  race_other
# 0             73      2576         200
# 1             77     10800         478
# 2             26      1761          62
# 3             47      1649          10
# 4            353     11870        1940

# %% [markdown]
# ## Define occ_title group
#
# These are our predefined group that we can pass into PostGres later. For now we pass into our **isin** filter next step.
#
# For final presentation, these job_groups can be a select drop-down to see the same analysis run against several different job categories.
#
# I scrolled through all the jobs list and manually read and extracted the occ_titles that fits "technical". I will revisit this.

# %%
job_groups = {
    'technical' : ['Management Occupations','Computer and Information Systems Managers', 'Computer and Mathematical Occupations', 'Computer Systems Analysts','Computer User Support Specialists', 'Network and Computer Systems Administrators', 'Software Developers and Software Quality Assurance Analysts and Testers', 'Computer Occupations, All Other', 'Computer Hardware Engineers', 'Information Security Analysts', 'Computer Network Support Specialists', 'Computer Network Architects', 'Database Administrators and Architects', 'Computer Programmers', 'Web Developers and Digital Interface Designers', 'Data Scientists and Mathematical Science Occupations, All Other', 'Computer Numerically Controlled Tool Operators', 'Computer Numerically Controlled Tool Programmers', 'Computer and Information Research Scientists' ],
    'healthcare' : ['Registered Nurses', 'Nurse Practitioners', 'just examples']
}

job_groups['technical']
# Out:
# ['Management Occupations',
#  'Computer and Information Systems Managers',
#  'Computer and Mathematical Occupations',
#  'Computer Systems Analysts',
#  'Computer User Support Specialists',
#  'Network and Computer Systems Administrators',
#  'Software Developers and Software Quality Assurance Analysts and Testers',
#  'Computer Occupations, All Other',
#  'Computer Hardware Engineers',
#  'Information Security Analysts',
#  'Computer Network Support Specialists',
#  'Computer Network Architects',
#  'Database Administrators and Architects',
#  'Computer Programmers',
#  'Web Developers and Digital Interface Designers',
#  'Data Scientists and Mathematical Science Occupations, All Other',
#  'Computer Numerically Controlled Tool Operators',
#  'Computer Numerically Controlled Tool Programmers',
#  'Computer and Information Research Scientists']

# %% [markdown]
# ## Flag BLS row as istech if occ_title isin list
#
# Creates a filtered DF where occ_title is in our Titles list defined above

# %%
#filteredBLS_df = BLS_df.loc[BLS_df['occ_title'].isin(job_groups['technical'])]
filteredBLS_df = BLS_df
filteredBLS_df['istech'] = np.where(filteredBLS_df["occ_title"].isin(job_groups['technical']), 1, 0)
filteredBLS_df
# Out:
#               area_title                                          occ_title  \
# 1            Abilene, TX                             Management Occupations
# 18           Abilene, TX      Business and Financial Operations Occupations
# 34           Abilene, TX              Computer and Mathematical Occupations
# 41           Abilene, TX           Architecture and Engineering Occupations
# 51           Abilene, TX     Life, Physical, and Social Science Occupations
# ...                  ...                                                ...
# 139927  Worcester, MA-CT         Farming, Fishing, and Forestry Occupations
# 139930  Worcester, MA-CT            Construction and Extraction Occupations
# 139955  Worcester, MA-CT  Installation, Maintenance, and Repair Occupations
# 139980  Worcester, MA-CT                             Production Occupations
# 140032  Worcester, MA-CT     Transportation and Material Moving Occupations
#
#         tot_emp  jobs_1000  istech
# 1          2910     44.068       1
# 18         2150     32.515       0
# 34          820     12.372       1
# 41          840     12.765       0
# 51          370      5.554       0
# ...         ...        ...     ...
# 139927      330      1.251       0
# 139930     9110     34.244       0
# 139955     9160     34.437       0
# 139980    18430     69.277       0
# 140032    21710     81.611       0
#
# [8368 rows x 5 columns]

# %% [markdown]
# ### Group by area_title
#
# #### Note: Only including jobs_1000 here to keep column ordering, will calculate actual jobs_1000 values below

# %%
merged_grouped = filteredBLS_df.groupby(['area_title', 'istech'], as_index=False).agg(
    area_title = ('area_title', lambda x: x.iloc[0]),
    tot_emp = ('tot_emp', 'sum'),
    jobs_1000 = ('jobs_1000', lambda x: 0)
    )

# %% [markdown]
# # Merge the filtered BLS with the Demographic DF on 'area_title'
#
# This creates a DataFrame matching all merged_grouped['area_title'] to demographic_df on 'area_title'

# %%
tech_not_tech_df = pd.merge(merged_grouped, demographic_df, on=['area_title'])

# %% [markdown]
# ## Scale the tot_emp with 'All Occupations'
#
# When summing up all individual jobs in an area, the **tot_emp** count exceeds the population count. Total employement value always exceeds the BLS row **All Occupations** which represents

# %%
# Add new columns to hold our calculated values
#tech_not_tech_df.insert(3,'tot_emp_scaled', 0)
#tech_not_tech_df.insert(4,'all_occupations', 0)
tech_not_tech_df.insert(3,'sum_area_occupations', 0)

# %%
for i, row in tech_not_tech_df.iterrows():
    
    # tot_emp value where occ_title == 'All Occupations'
    ifor_val_all_occupations = BLS[BLS["area_title"].isin([row['area_title']]) & BLS["occ_title"].isin(["All Occupations"])]['tot_emp'].astype(int)
    
    # SUM of tot_emp values matching 'area_title' where occ_title != 'All Occupations';
    ifor_val_sum_area_tot_emp = BLS[BLS["area_title"].isin([row['area_title']]) & ~BLS["occ_title"].isin(["All Occupations"])]['tot_emp'].sum().astype(int)
    
    #scale this row's tot_emp  by  (all_occupation_row_tot_emp * this.row_tot_temp) / sum of all occ_title in this area not All Occupations
    #ifor_val_scaled = (ifor_val_all_occupations * row['tot_emp']) / ifor_val_sum_area_tot_emp
    #ifor_val_scaled = row['tot_emp']
    # assign values to each of the 3 new columns
    #tech_not_tech_df.at[i,'all_occupations'] = ifor_val_all_occupations
    tech_not_tech_df.at[i,'sum_area_occupations'] = ifor_val_sum_area_tot_emp
    #tech_not_tech_df.at[i,'tot_emp_scaled'] = ifor_val_scaled

# %% [markdown]
# ## Calculate jobs_1000

# %%
tech_not_tech_df['jobs_1000'] = round(( tech_not_tech_df['tot_emp'] / tech_not_tech_df['population']) * 1000).astype(int)

# %% [markdown]
# # Dataset 1: Grouped by TECHNICAL and NON-TECHNICAL

# %% [markdown]
# ### Check our final DF

# %%
tech_not_tech_df.head(10)
# Out:
#    istech       area_title  tot_emp  sum_area_occupations  jobs_1000  \
# 0       0      Abilene, TX    62340                 66070        466
# 1       1      Abilene, TX     3730                 66070         28
# 2       0        Akron, OH   286770                311500        765
# 3       1        Akron, OH    24730                311500         66
# 4       0       Albany, GA    52080                 55640        531
# 5       1       Albany, GA     3560                 55640         36
# 6       0       Albany, OR    40410                 42720        636
# 7       1       Albany, OR     2310                 42720         36
# 8       0  Albuquerque, NM   346590                374380        543
# 9       1  Albuquerque, NM    27790                374380         44
#
#          area_name  population  median_age  average_income  family_poverty  \
# 0      Abilene, TX      133731          29           52989           16198
# 1      Abilene, TX      133731          29           52989           16198
# 2        Akron, OH      374675          38           57023           52405
# 3        Akron, OH      374675          38           57023           52405
# 4       Albany, GA       98002          35           53876           24957
# 5       Albany, GA       98002          35           53876           24957
# 6       Albany, OR       63503          38           72395            6409
# 7       Albany, OR       63503          38           72395            6409
# 8  Albuquerque, NM      638803          36           66708           92558
# 9  Albuquerque, NM      638803          36           66708           92558
#
#    ...  educational_attainment_no_diploma  \
# 0  ...                              19258
# 1  ...                              19258
# 2  ...                              41708
# 3  ...                              41708
# 4  ...                              16919
# 5  ...                              16919
# 6  ...                               5150
# 7  ...                               5150
# 8  ...                              78799
# 9  ...                              78799
#
#    educational_attainment_some_college  race_asian  race_white  race_black  \
# 0                                43669        2626       81145       12275
# 1                                43669        2626       81145       12275
# 2                               110658        9945      279041       66305
# 3                               110658        9945      279041       66305
# 4                                32046         959       28981       63178
# 5                                32046         959       28981       63178
# 6                                26013        1185       52553         367
# 7                                26013        1185       52553         367
# 8                               203804       14485      252843       16466
# 9                               203804       14485      252843       16466
#
#    race_hispanic  race_native  race_islander  race_two  race_other
# 0          34147          689             73      2576         200
# 1          34147          689             73      2576         200
# 2           7245          784             77     10800         478
# 3           7245          784             77     10800         478
# 4           2916          119             26      1761          62
# 5           2916          119             26      1761          62
# 6           7282          410             47      1649          10
# 7           7282          410             47      1649          10
# 8         317922        22924            353     11870        1940
# 9         317922        22924            353     11870        1940
#
# [10 rows x 23 columns]

# %%
# write to csv
tech_not_tech_df.to_csv('../data_files/Jobs_Tech_Not_Tech_by_Area_Title_df.csv')

# %% [markdown]
# # Dataset 2:  Grouped by TECHNICAL-ONLY Dataframe

# %%
techonly_df = tech_not_tech_df[tech_not_tech_df['istech']==1]
techonly_df.head(10)
# Out:
#     istech       area_title  tot_emp  sum_area_occupations  jobs_1000  \
# 1        1      Abilene, TX     3730                 66070         28
# 3        1        Akron, OH    24730                311500         66
# 5        1       Albany, GA     3560                 55640         36
# 7        1       Albany, OR     2310                 42720         36
# 9        1  Albuquerque, NM    27790                374380         44
# 11       1   Alexandria, LA     2770                 57140         43
# 13       1      Altoona, PA     2920                 54790         47
# 15       1     Amarillo, TX     6250                107860         27
# 17       1         Ames, IA     4170                 42980         60
# 19       1    Anchorage, AK    14980                164500         17
#
#           area_name  population  median_age  average_income  family_poverty  \
# 1       Abilene, TX      133731          29           52989           16198
# 3         Akron, OH      374675          38           57023           52405
# 5        Albany, GA       98002          35           53876           24957
# 7        Albany, OR       63503          38           72395            6409
# 9   Albuquerque, NM      638803          36           66708           92558
# 11   Alexandria, LA       64782          40           58470           11744
# 13      Altoona, PA       61762          40           55368            9357
# 15     Amarillo, TX      227906          36           72544           28207
# 17         Ames, IA       69189          22           35781            2342
# 19    Anchorage, AK      906735          34          103078           50058
#
#     ...  educational_attainment_no_diploma  \
# 1   ...                              19258
# 3   ...                              41708
# 5   ...                              16919
# 7   ...                               5150
# 9   ...                              78799
# 11  ...                               9809
# 13  ...                               6570
# 15  ...                              38650
# 17  ...                               1540
# 19  ...                              58227
#
#     educational_attainment_some_college  race_asian  race_white  race_black  \
# 1                                 43669        2626       81145       12275
# 3                                110658        9945      279041       66305
# 5                                 32046         959       28981       63178
# 7                                 26013        1185       52553         367
# 9                                203804       14485      252843       16466
# 11                                17446        1862       27828       32237
# 13                                14736         190       57740        1486
# 15                                78994        8040      131730       14345
# 17                                13890        6813       55861        1683
# 19                               320844       82416      539625       46959
#
#     race_hispanic  race_native  race_islander  race_two  race_other
# 1           34147          689             73      2576         200
# 3            7245          784             77     10800         478
# 5            2916          119             26      1761          62
# 7            7282          410             47      1649          10
# 9          317922        22924            353     11870        1940
# 11           1587          226              7      1004          31
# 13            934            0              7      1386          19
# 15          68070          829            174      4539         179
# 17           2352          175             34      2257          14
# 19          79809        61260          20832     73740        2094
#
# [10 rows x 23 columns]

# %%
# write to csv
techonly_df.to_csv('../data_files/Jobs_Tech_by_Area_Title_df.csv')

# %% [markdown]
# # Dataset 3: Grouped by entire ALL of AREA regardless of job type
#
# ## Analyzing employment data as a whole
#
# **Just Brainstorming while going through this data**
#
# How we can use this dataset is lets say, we have "family_poverty" as the target, and the demographic and jobs_1000 and tot_emp as the independent variables. If we find a pattern with high accuracy to predict "family_poverty", then we can see which variable will help reduce "family_poverty". Could be reduce the median_age, or something as small as increasing the "average_income" by 2k, can reduce "family_poverty" by n%. Or increase the number of High School graduates.

# %%
# setting jobs_1000 as 0 to keep column order for human viewing
merged_grouped_all_df = tech_not_tech_df.groupby(['area_title'], as_index=False).agg(
    tot_emp = ('tot_emp', 'sum'),
    jobs_1000 = ('jobs_1000', lambda x: 0)
)

merged_grouped_all_df = pd.merge(merged_grouped_all_df, demographic_df, on=['area_title'])
merged_grouped_all_df['jobs_1000'] = round(( merged_grouped_all_df['tot_emp'] / merged_grouped_all_df['population']) * 1000).astype(int)
#merged_grouped_all_df.sort_values(by='jobs_1000', ascending=False)
merged_grouped_all_df
# Out:
#             area_title  tot_emp  jobs_1000          area_name  population  \
# 0          Abilene, TX    66070        494        Abilene, TX      133731
# 1            Akron, OH   311500        831          Akron, OH      374675
# 2           Albany, GA    55640        568         Albany, GA       98002
# 3           Albany, OR    42720        673         Albany, OR       63503
# 4      Albuquerque, NM   374380        586    Albuquerque, NM      638803
# ..                 ...      ...        ...                ...         ...
# 219     Wilmington, NC   126640        623     Wilmington, NC      203209
# 220  Winston-Salem, NC   257170        781  Winston-Salem, NC      329113
# 221         Yakima, WA    90240        618         Yakima, WA      145988
# 222      Yuba City, CA    41230        531      Yuba City, CA       77671
# 223           Yuma, AZ    60640        138           Yuma, AZ      437889
#
#      median_age  average_income  family_poverty  \
# 0            29           52989           16198
# 1            38           57023           52405
# 2            35           53876           24957
# 3            38           72395            6409
# 4            36           66708           92558
# ..          ...             ...             ...
# 219          38           73390           24661
# 220          36           62399           45209
# 221          35           66839           19693
# 222          36           71409           11213
# 223          31           57210           76140
#
#      educational_attainment_bachelors  educational_attainment_graduate  ...  \
# 0                               19975                             9695  ...
# 1                               60910                            29186  ...
# 2                               11517                             8460  ...
# 3                               11043                             5806  ...
# 4                              111538                            91807  ...
# ..                                ...                              ...  ...
# 219                             52916                            26429  ...
# 220                             67318                            37479  ...
# 221                             16594                            10781  ...
# 222                              9668                             4388  ...
# 223                             40521                            24318  ...
#
#      educational_attainment_no_diploma  educational_attainment_some_college  \
# 0                                19258                                43669
# 1                                41708                               110658
# 2                                16919                                32046
# 3                                 5150                                26013
# 4                                78799                               203804
# ..                                 ...                                  ...
# 219                              15960                                63855
# 220                              37954                               101423
# 221                              31723                                46357
# 222                              16067                                28376
# 223                             117537                               142179
#
#      race_asian  race_white  race_black  race_hispanic  race_native  \
# 0          2626       81145       12275          34147          689
# 1          9945      279041       66305           7245          784
# 2           959       28981       63178           2916          119
# 3          1185       52553         367           7282          410
# 4         14485      252843       16466         317922        22924
# ..          ...         ...         ...            ...          ...
# 219        2824      155339       28915          11206          563
# 220        6948      193899       82010          38918          508
# 221        1392       84786        1349          53274         1791
# 222       13478       35947        1668          22226          459
# 223        6261      137175       10539         271845         4950
#
#      race_islander  race_two  race_other
# 0               73      2576         200
# 1               77     10800         478
# 2               26      1761          62
# 3               47      1649          10
# 4              353     11870        1940
# ..             ...       ...         ...
# 219            151      3894         317
# 220            165      5574        1091
# 221            109      3207          80
# 222            324      3406         163
# 223            231      6663         225
#
# [224 rows x 21 columns]

# %%
merged_grouped_all_df[merged_grouped_all_df['jobs_1000']>1000].shape
# Out:
# (41, 21)

# %%
merged_grouped_all_df[merged_grouped_all_df['jobs_1000']<1000].shape
# Out:
# (183, 21)

# %%
# write to csv
merged_grouped_all_df.to_csv('../data_files/Jobs_All_by_Area_Title_df.csv')

# %% [markdown]
# # Validating Data
#
# Keep below to test and modify if needed

# %% [markdown]
# ## Evaluate an Area

# %%
search_area = "Akron, OH"
area_df = BLS[BLS["area_title"].isin([search_area])]

# %% [markdown]
# ## 1. Get tot_emp value in column 'occ_title' is ALL OCCUPATIONS

# %%
all_occupations_df = area_df[area_df['occ_title']=='All Occupations'].tot_emp.astype(int)

# %% [markdown]
# ## 2. Agg sum of tot_emp value in columns 'occ_title' is NOT ALL OCCUPATIONS

# %%
all_titles_sum_df = area_df[area_df['occ_title']!='All Occupations']
all_titles_sum_df = all_titles_sum_df.groupby(['area_title'], as_index=False).agg(
    area_title = ('area_title', lambda x: x.iloc[0]),
    tot_emp = ('tot_emp', 'sum')
    )

# %% [markdown]
# ## 3. Population for this area

# %%
area_population = demographic_df[demographic_df['area_title']==search_area]['population']

# %% [markdown]
# ## 4. Compare BLS's All Occupation row count with the SUM of tot_emp
#
# Note: The SUM of all other tot_emp does not include the row where occ_title == 'All Occupations'

# %%
print (f"The population for {search_area} is {area_population.iat[0]}")
print (f"This is what BLS data says is the number of 'All Occupations in' {search_area} {all_occupations_df.iat[0]}")
print (f"This is the SUM of all other occupations in {search_area} {all_titles_sum_df.iat[0,1].astype(int)}")
# Out:
# The population for Akron, OH is 374675
# This is what BLS data says is the number of 'All Occupations in' Akron, OH 311480
# This is the SUM of all other occupations in Akron, OH 311500

# %% [markdown]
# # Scale the SUM tot_emp with the All Occupations tot_emp value
#
# ### (IGNORE BELOW) ###

# %%
test_df = tech_not_tech_df.copy()

# %%
test_agg_df = test_df.copy()
#test_agg_df.insert(3,'tot_emp_scaled', 0)
#test_agg_df.insert(4,'all_occupations', 0)
#test_agg_df.insert(5,'sum_area_occupations', 0)

# %%
#    Numbers have been altered for comprehension
#    BLS occ_title "All Occupation" row for Akron Ohio says there are 50 tot_emp
#    Our SUMs says we counted 120 tot_emp
#
#    100(non-tech) and 20 (tech)
#    
#    120 (false tot_emp)      50 (BLS single row 'All Occupations' value)
#    -------------       =  --------------- 
#    100(non-tech)          ===> scaled-non-tech = 42 <===
#    
#    120 (false tot_emp)      50 (BLS single row 'All Occupations' value)
#    -------------       =  ---------------
#    20(tech)               ===> scaled-non-tech  8 <===


for i, row in test_agg_df.iterrows():
    
    # tot_emp value where occ_title == 'All Occupations'
    #ifor_val_all_occupations = BLS[BLS["area_title"].isin([row['area_title']]) & BLS["occ_title"].isin(["All Occupations"])]['tot_emp'].astype(int)
    
    # SUM of tot_emp values matching 'area_title' where occ_title != 'All Occupations';
    #ifor_val_sum_area_tot_emp = BLS[BLS["area_title"].isin([row['area_title']]) & ~BLS["occ_title"].isin(["All Occupations"])]['tot_emp'].sum().astype(int)

    # scale this row's tot_emp  by  (all_occupation_row_tot_emp * this.row_tot_temp) / sum of all occ_title in this area not All Occupations
    #ifor_val_scaled = (ifor_val_all_occupations * row['tot_emp']) / ifor_val_sum_area_tot_emp
    
    # assign values to each of the 3 new columns
    #test_agg_df.at[i,'all_occupations'] = ifor_val_all_occupations
    #test_agg_df.at[i,'sum_area_occupations'] = ifor_val_sum_area_tot_emp
    #test_agg_df.at[i,'tot_emp_scaled'] = ifor_val_scaled
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'tot_emp_scaled'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/frame.py in _set_value(self, index, col, value, takeable)
#    3264
# -> 3265             series = self._get_item_cache(col)
#    3266             engine = self.index._engine
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    3790
# -> 3791             loc = self.columns.get_loc(item)
#    3792             values = self._mgr.iget(loc)
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#
# KeyError: 'tot_emp_scaled'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-3892b6e4111b> in <module>
#      28     #test_agg_df.at[i,'all_occupations'] = ifor_val_all_occupations
#      29     test_agg_df.at[i,'sum_area_occupations'] = ifor_val_sum_area_tot_emp
# ---> 30     test_agg_df.at[i,'tot_emp_scaled'] = ifor_val_scaled
#      31
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#    2165             return
#    2166
# -> 2167         return super().__setitem__(key, value)
#    2168
#    2169
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#    2116             raise ValueError("Not enough indexers for scalar access (setting)!")
#    2117
# -> 2118         self.obj._set_value(*key, value=value, takeable=self._takeable)
#    2119
#    2120
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/frame.py in _set_value(self, index, col, value, takeable)
#    3276                 self.iloc[index, col] = value
#    3277             else:
# -> 3278                 self.loc[index, col] = value
#    3279             self._item_cache.pop(col, None)
#    3280
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     690
#     691         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 692         iloc._setitem_with_indexer(indexer, value, self.name)
#     693
#     694     def _validate_key(self, key, axis: int):
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value, name)
#    1602                             indexer, self.obj.axes
#    1603                         )
# -> 1604                         self._setitem_with_indexer(new_indexer, value, name)
#    1605
#    1606                         return
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value, name)
#    1633         if take_split_path:
#    1634             # We have to operate column-wise
# -> 1635             self._setitem_with_indexer_split_path(indexer, value, name)
#    1636         else:
#    1637             self._setitem_single_block(indexer, value, name)
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexing.py in _setitem_with_indexer_split_path(self, indexer, value, name)
#    1652
#    1653         if isinstance(value, ABCSeries) and name != "iloc":
# -> 1654             value = self._align_series(indexer, value)
#    1655
#    1656         # Ensure we have something we can iterate over
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexing.py in _align_series(self, indexer, ser, multiindex_indexer)
#    2028             return ser.reindex(ax)._values
#    2029
# -> 2030         raise ValueError("Incompatible indexer with Series")
#    2031
#    2032     def _align_frame(self, indexer, df: "DataFrame"):
#
# ValueError: Incompatible indexer with Series

# %%
test_agg_df[test_agg_df['area_title']==search_area]

# %% [markdown]
# ## ToDo: Define outliers

# %%
test_agg_df[test_agg_df['jobs_1000'] > 1000]
