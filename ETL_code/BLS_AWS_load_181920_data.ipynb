# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
import psycopg2

# %%
pd.set_option('display.max_columns', None)

# %%
file_metro = "..\data_files\merged_metrodata_181920.csv"
bls_metro_df = pd.read_csv(file_metro)
bls_metro_df.head()
# Out:
#    Unnamed: 0   area     citi_state occ_code  \
# 0           0  11260  Anchorage, AK  00-0000
# 1           1  11260  Anchorage, AK  11-0000
# 2           2  11260  Anchorage, AK  11-2011
# 3           3  11260  Anchorage, AK  11-2021
# 4           4  11260  Anchorage, AK  11-2031
#
#                                    occ_title   tot_emp  emp_prse  jobs_1000  \
# 0                            All Occupations  171770.0       1.1   1000.000
# 1                     Management Occupations   10610.0       2.5     61.779
# 2        Advertising and Promotions Managers      50.0      16.5      0.282
# 3                         Marketing Managers     150.0      12.9      0.867
# 4  Public Relations and Fundraising Managers     100.0      13.7      0.557
#
#    loc_quotient  h_mean    a_mean  mean_prse  h_pct10  h_pct25  h_median  \
# 0          1.00   28.57   59430.0        2.1    11.41    14.94     22.68
# 1          1.17   55.59  115630.0        1.8    26.68    36.03     48.94
# ...

# %% [markdown]
# Remove the comment to have dataFrames load to postGres DB

# %%
from config import AWS

# %%
#connecting to postgres DB to create a new table
engine = create_engine(AWS)

bls_metro_df.to_sql('blsmetro', engine, if_exists='replace')
