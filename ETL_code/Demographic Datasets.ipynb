# %% [markdown]
# # Demographics DataFrames
#
# This serves as the master demographics data view. This is a WIP and will update as we continue to clean up location parsing.

# %%
import pandas as pd

# %% [markdown]
# ## Read data

# %%
tech_not_tech_df = pd.read_csv('../data_files/Jobs_Tech_Not_Tech_by_Area_Title_df.csv', index_col=[0], header=0)
tech_df = pd.read_csv('../data_files/Jobs_Tech_by_Area_Title_df.csv', index_col=[0], header=0)
all_jobs_df = pd.read_csv('../data_files/Jobs_All_by_Area_Title_df.csv', index_col=[0], header=0)

# %% [markdown]
# ## Dataset 1:  Tech not Tech

# %%
tech_not_tech_df.sort_values(by='jobs_1000', ascending=False)
# Out:
#      istech       area_title  tot_emp  jobs_1000        area_name  population  \
# 40        0      Beckley, WV    38320      59319      Beckley, WV         646
# 427       0       Wausau, WI    64390      22059       Wausau, WI        2919
# 176       0   Hinesville, GA    16350      10381   Hinesville, GA        1575
# 188       0       Ithaca, NY    41890       4818       Ithaca, NY        8695
# 41        1      Beckley, WV     2090       3235      Beckley, WV         646
# ..      ...              ...      ...        ...              ...         ...
# 147       1      Gadsden, AL     1230          5      Gadsden, AL      237057
# 288       1         Napa, CA      600          5         Napa, CA      117077
# 416       1     Valdosta, GA      340          4     Valdosta, GA       95423
# 151       1  Gainesville, GA      570          4  Gainesville, GA      136696
# 426       1    Waterbury, CT      550          3    Waterbury, CT      157666
#
# ...

# %% [markdown]
# ## Dataset 2: Tech only

# %%
tech_df
#tech_df.sort_values(by='jobs_1000', ascending=False)
# Out:
#      istech         area_title  tot_emp  jobs_1000          area_name  \
# 1         1        Abilene, TX     3730         28        Abilene, TX
# 3         1          Akron, OH    24730         66          Akron, OH
# 5         1         Albany, GA     3560         36         Albany, GA
# 7         1         Albany, OR     2310         36         Albany, OR
# 9         1    Albuquerque, NM    27790         44    Albuquerque, NM
# ..      ...                ...      ...        ...                ...
# 438       1     Wilmington, NC     8800         43     Wilmington, NC
# 440       1  Winston-Salem, NC    16300         50  Winston-Salem, NC
# 442       1         Yakima, WA     3570         24         Yakima, WA
# 444       1      Yuba City, CA     2270         29      Yuba City, CA
# 446       1           Yuma, AZ     3300          8           Yuma, AZ
#
#      population  median_age  average_income  family_poverty  \
# 1        133731          29           52989           16198
# ...

# %% [markdown]
# ## Dataset 3: All data grouped by area_title only

# %%
all_jobs_df
# Out:
#             area_title  tot_emp  jobs_1000          area_name  population  \
# 0          Abilene, TX    66070        494        Abilene, TX      133731
# 1            Akron, OH   311500        831          Akron, OH      374675
# 2           Albany, GA    55640        568         Albany, GA       98002
# 3           Albany, OR    42720        673         Albany, OR       63503
# 4      Albuquerque, NM   374380        586    Albuquerque, NM      638803
# ..                 ...      ...        ...                ...         ...
# 219     Wilmington, NC   126640        623     Wilmington, NC      203209
# 220  Winston-Salem, NC   257170        781  Winston-Salem, NC      329113
# 221         Yakima, WA    90240        618         Yakima, WA      145988
# 222      Yuba City, CA    41230        531      Yuba City, CA       77671
# 223           Yuma, AZ    60640        138           Yuma, AZ      437889
#
#      median_age  average_income  family_poverty  \
# ...
