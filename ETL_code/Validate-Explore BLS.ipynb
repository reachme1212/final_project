# %% [markdown]
# # Validate BLS data

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Source

# %%
demographic_df = pd.read_csv('../data_files/metro_demographic_by_city_state.csv', index_col=[0], header=0)
BLS = pd.read_csv('../data_files/bls_metro_2020_clean.csv', index_col=[0], header=0)

# %%
search_area = "Beckley, WV"

# %%
all_occupation_row_df = BLS[(BLS['occ_title']=='All Occupations') & (BLS['area_title']==search_area)]
all_occupation_row_df
# Out:
#         area   area_title prim_state occ_code        occ_title o_group  \
# 10979  13220  Beckley, WV         WV  00-0000  All Occupations   total
#
#        tot_emp  emp_prse  jobs_1000  loc_quotient  ...  h_pct10  h_pct25  \
# 10979  40400.0       3.4     1000.0           1.0  ...     9.54    11.21
#
#        h_median  h_pct75  h_pct90  a_pct10  a_pct25  a_median  a_pct75  \
# 10979      15.8    24.08    34.87  19850.0  23320.0   32850.0  50080.0
#
#        a_pct90
# 10979  72540.0
#
# [1 rows x 23 columns]

# %%
area_df = BLS[(BLS['area_title']==search_area) & (BLS['occ_title']!='All Occupations') ]
area_df.sort_values(by='tot_emp', ascending=False).head(20)
# Out:
#         area   area_title prim_state occ_code  \
# 11112  13220  Beckley, WV         WV  43-0000
# 11101  13220  Beckley, WV         WV  41-0000
# 11075  13220  Beckley, WV         WV  35-0000
# 11041  13220  Beckley, WV         WV  29-0000
# 11172  13220  Beckley, WV         WV  53-0000
# 11138  13220  Beckley, WV         WV  47-0000
# 11062  13220  Beckley, WV         WV  31-0000
# 11149  13220  Beckley, WV         WV  49-0000
# 11029  13220  Beckley, WV         WV  25-0000
# 10980  13220  Beckley, WV         WV  11-0000
# 11103  13220  Beckley, WV         WV  41-2011
# 11069  13220  Beckley, WV         WV  33-0000
# 11063  13220  Beckley, WV         WV  31-1120
# 11082  13220  Beckley, WV         WV  35-3023
# 11086  13220  Beckley, WV         WV  37-0000
# 10991  13220  Beckley, WV         WV  13-0000
# 11161  13220  Beckley, WV         WV  51-0000
# 11048  13220  Beckley, WV         WV  29-1141
# 11106  13220  Beckley, WV         WV  41-2031
# ...

# %%
area_df['occ_title'].shape
# Out:
# (178,)

# %%
area_df['occ_title'].unique().shape
# Out:
# (178,)

# %%
area_df['tot_emp'].sum()
# Out:
# 72310.0

# %%
area_major_df = BLS[(BLS['area_title']==search_area) & (BLS['occ_title']!='All Occupations') & (BLS['o_group']=='major') ]
area_major_df.sort_values(by='tot_emp', ascending=False).head()
# Out:
#         area   area_title prim_state occ_code  \
# 11112  13220  Beckley, WV         WV  43-0000
# 11101  13220  Beckley, WV         WV  41-0000
# 11075  13220  Beckley, WV         WV  35-0000
# 11041  13220  Beckley, WV         WV  29-0000
# 11172  13220  Beckley, WV         WV  53-0000
#
#                                                occ_title o_group  tot_emp  \
# 11112      Office and Administrative Support Occupations   major   5130.0
# 11101                      Sales and Related Occupations   major   4100.0
# 11075   Food Preparation and Serving Related Occupations   major   3860.0
# 11041  Healthcare Practitioners and Technical Occupat...   major   3730.0
# 11172     Transportation and Material Moving Occupations   major   3330.0
#
#        emp_prse  jobs_1000  loc_quotient  ...  h_pct10  h_pct25  h_median  \
# 11112       4.1    127.037          0.95  ...     9.79    12.30     14.92
# 11101      13.5    101.354          1.07  ...     9.65    10.02     12.27
# ...

# %%
print (f"Sum of all major occ_titles in {search_area} is {area_major_df['tot_emp'].sum().astype(int)}")
# Out:
# Sum of all major occ_titles in Beckley, WV is 40410
