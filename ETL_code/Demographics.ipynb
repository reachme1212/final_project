# %% [markdown]
# # Demographics DataFrames
#
# This serves as the master demographics data view. This is a WIP and will update as we continue to clean up location parsing.

# %%
import pandas as pd

# %% [markdown]
# ## By Zipcode

# %%
demo_zipcode = pd.read_csv('../data_files/metro_demographic_by_zipcode.csv', index_col=[0], header=0)
demo_zipcode
# Out:
#      zipcode          state        city  population  median_age  race_asian  \
# 0      99501         Alaska   Anchorage       17084          34         999
# 1      99502         Alaska   Anchorage       24505          32        2028
# 2      99503         Alaska   Anchorage       13668          34        2102
# 3      99504         Alaska   Anchorage       42161          32        4251
# 4      99505         Alaska   Anchorage        6477          21         188
# ..       ...            ...         ...         ...         ...         ...
# 842    53706      Wisconsin     Madison        6265          19         991
# 843    53715      Wisconsin     Madison       14246          22        1697
# 844    53726      Wisconsin     Madison        5869          23         716
# 845    25301  West Virginia  Charleston        2360          47          48
# 846    25304  West Virginia  Charleston        8307          42         297
#
# ...

# %%
demo_zipcode.shape
# Out:
# (818, 21)

# %% [markdown]
# ## By City, State (aka Metropolitan area)
#
# ### Most are just city and state, (wip) cluster of cities and/or states
#
# Demo_zipcode grouped by **city** and **state**
#
# **sum()** all numeric columns
#
# exception
#
# **mean()** average_income

# %%
demo_city_state = pd.read_csv('../data_files/metro_demographic_by_city_state.csv', index_col=[0], header=0)
demo_city_state
# Out:
#               city           state  population  median_age  average_income  \
# 0          Abilene           Texas       85075          27           49583
# 1            Akron            Ohio       94894          33           42943
# 2           Albany         Georgia       64884          37           59234
# 3      Albuquerque      New Mexico      319991          35           61589
# 4       Alexandria       Louisiana       59184          38           57892
# ..             ...             ...         ...         ...             ...
# 150        Wichita          Kansas      191734          34           75391
# 151  Wichita Falls           Texas       65896          31           56167
# 152  Winston-Salem  North Carolina       33082          27           34263
# 153         Yakima      Washington       46258          32           52787
# 154      Yuba City      California       40959          33           60353
#
#      family_poverty  educational_attainment_bachelors  \
# ...

# %%
demo_city_state.shape
# Out:
# (155, 19)
